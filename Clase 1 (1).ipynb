# %% [markdown]
# ## Clase 1 - Introduccion a Python

# %%
print('hola')
# Out:
# hola

# %% [markdown]
# Cargando las librerias

# %%
import numpy as np

# %%
x = 50 
y = np.random.rand(x)
y
# Out:
# array([2.56040520e-01, 8.63243925e-01, 9.42932807e-01, 8.73453697e-01,
#        5.83912749e-01, 4.96564308e-01, 1.02676896e-06, 3.68061290e-01,
#        5.07736429e-01, 1.89193102e-01, 8.66261015e-01, 7.91340544e-01,
#        7.94446052e-01, 6.20264443e-01, 6.07842314e-01, 1.91355103e-01,
#        2.18386621e-01, 2.88953163e-01, 9.07612929e-01, 1.31746301e-02,
#        9.27184394e-01, 3.78963483e-01, 3.53635033e-01, 5.77981050e-01,
#        9.04577202e-01, 9.54362520e-02, 1.07787953e-01, 4.83079316e-01,
#        7.92770402e-01, 2.28046619e-01, 7.04768416e-01, 3.69602358e-01,
#        1.09289116e-01, 5.30836747e-01, 1.47158247e-01, 2.69540454e-01,
#        4.42770213e-01, 2.35983860e-01, 3.15769649e-01, 9.76182581e-01,
#        3.71555751e-01, 7.79680303e-02, 6.39790534e-01, 8.18004713e-01,
#        2.37932927e-01, 8.14744358e-01, 7.14826285e-01, 3.23102458e-01,
#        8.13912962e-01, 5.79783014e-01])

# %%
# %ls  datasets/
# Out:
# adult.csv                  census.csv     movies.csv
# airline_data.csv           coches.csv     nhanes_2015_2016.csv
# antropometria00.csv        cwurData.csv   pokemon.csv
# antropometria-dataset.csv  data.csv       sample_pivot.csv
# Book3.csv                  headbrain.csv  tips.csv
# Canada.xlsx                mic2.xlsx      weight-height.csv
# Cartwheeldata.csv          mic.xlsx

# %% [markdown]
# ## Tipos de los datos

# %%
import math

# %%
type(4)
# Out:
# int

# %%
type(4.0)
# Out:
# float

# %%
type(-3)
# Out:
# int

# %%
x = 'nombre1'
x
# Out:
# 'nombre1'

# %%
type(x)
# Out:
# str

# %%
numbers = [1,2,3,4,5]
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
type(numbers)
# Out:
# list

# %%
numbers[0]
# Out:
# 1

# %%
numbers[4]
# Out:
# 5

# %%
sum_numbers = sum(numbers)
sum_numbers
# Out:
# 15

# %%
lenth = len(numbers)
lenth
# Out:
# 5

# %%
promedio = sum_numbers/lenth
promedio
# Out:
# 3.0

# %%
type(3/5)
# Out:
# float

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
type(math.pi)
# Out:
# float

# %%
type('math.pi')
# Out:
# str

# %%
numbers = [math.pi, 3/5, 4.0, 'nombre', True]

# %%
type(False)
# Out:
# bool

# %%
type('True')
# Out:
# str

# %%
print(None)
# Out:
# None

# %%
type(None)
# Out:
# NoneType

# %%
x = 16
y = 8
if x < y:
    print('{} es menor que {}'.format(x,y))
else:
     print(x, 'es menor que', y)
# Out:
# 16 es menor que 8

# %%
unaLista = [True, 6<5, 1==3, None is None]
unaLista
# Out:
# [True, False, False, True]

# %% [markdown]
# ## El uso de for loop

# %%
for element in unaLista:
    print(element,'   ', type(element))
# Out:
# True     <class 'bool'>
# False     <class 'bool'>
# False     <class 'bool'>
# True     <class 'bool'>

# %% [markdown]
# # Lista

# %%
unaLista = ['first', 'second', 'third', 'forth', 'fifth', 'sixth']
unaLista
# Out:
# ['first', 'second', 'third', 'forth', 'fifth', 'sixth']

# %%
#unaLista.sort()
#unaLista

# %%
unaLista[:2]
# Out:
# ['first', 'second']

# %%
unaLista[:]
# Out:
# ['first', 'second', 'third', 'forth', 'fifth']

# %%
unaLista[1:3]
# Out:
# ['second', 'third']

# %%
unaLista[5]
# Out:
# 'sixth'

# %%
unaLista[-1:]
# Out:
# ['sixth']

# %%
unaLista[-3:-1]
# Out:
# ['forth', 'fifth']
